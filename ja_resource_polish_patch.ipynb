# %% [markdown]
# # Japanese Resource Page Polish
#
# This notebook patches Japanese resource pages to align with the polished English resource page design, adding toolbar, localized canonical URLs, and shared polish CSS where needed.

# %%
import glob
import os
import re
from pathlib import Path

root = Path.cwd() / 'ja' / 'resources'
files = sorted(root.glob('*.html'))
print('Found', len(files), 'Japanese resource pages to inspect.')
